# %%
import pandas as pd
df=pd.read_csv("/content/student_habits_performance.csv")

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
df.isna().sum().sum() #checks the null values in dataset
# Out:
# np.int64(91)

# %%
df=df.dropna() #drops the null values from the dataset

# %%
df.isna().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
df.duplicated().sum() #return boolean type true or false if there are duplicate values
# Out:
# np.int64(0)

# %%
import warnings
warnings.filterwarnings("ignore") #ignores the future warnings in code execution

# %%
df.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  909.000000           909.000000          909.000000     909.000000
# mean    20.475248             3.538724            2.504620       1.830363
# std      2.302721             1.469730            1.164802       1.071251
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.600000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# ...

# %%
df.describe(include="object").columns #summary of categorical columns
# Out:
# Index(['student_id', 'gender', 'part_time_job', 'diet_quality',
#        'parental_education_level', 'internet_quality',
#        'extracurricular_participation'],
#       dtype='object')

# %%
categorical_cols=["gender","part_time_job","diet_quality","parental_education_level","internet_quality","extracurricular_participation"]

# %%
for col in categorical_cols:
  print(f"Value counts of {col}:\n{df[col].value_counts()}")
# Out:
# Value counts of gender:
# gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64
# Value counts of part_time_job:
# part_time_job
# No     713
# Yes    196
# Name: count, dtype: int64
# Value counts of diet_quality:
# diet_quality
# Fair    396
# Good    347
# Poor    166
# Name: count, dtype: int64
# Value counts of parental_education_level:
# parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Name: count, dtype: int64
# Value counts of internet_quality:
# internet_quality
# Good       410
# Average    352
# Poor       147
# Name: count, dtype: int64
# Value counts of extracurricular_participation:
# extracurricular_participation
# No     620
# Yes    289
# Name: count, dtype: int64

# %%
df.hist(bins=20,edgecolor="black")
plt.tight_layout()
plt.show()

# %%
for col in categorical_cols:
  sns.countplot(data=df,x=col)
  plt.title(f"Distribution of {col}")
  plt.xticks(rotation=45)
  plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="coolwarm",fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
df.describe().columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='object')

# %%
numeric_features=['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'exercise_frequency',
       'mental_health_rating']

# %%
for features in numeric_features:
  sns.scatterplot(data=df,x=features,y='exam_score')
  plt.title(f"{features}vs Exam score")
  plt.show()

# %%
for col in categorical_cols:
  sns.boxplot(data=df,x=col,y="exam_score")
  plt.title(f"Exam score by {col}")
  plt.xticks(rotation=45)
  plt.show()

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
features=['study_hours_per_day','attendance_percentage','mental_health_rating','sleep_hours','part_time_job']

# %%
target="exam_score"

# %%
df_model=df[features+[target]].copy()

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours part_time_job  exam_score
# 0            8.0            No        56.2
# ...

# %%
le=LabelEncoder() #to convet categorical values into numeric values we use labelencoder

# %%
df_model["part_time_job"]=le.fit_transform(df["part_time_job"])

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours  part_time_job  exam_score
# 0            8.0              0        56.2
# ...

# %%
X=df_model[features]

# %%
y=df_model[target]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
len(y_train)
# Out:
# 727

# %%
len(y_test)
# Out:
# 182

# %%
models={
    "LinearRegression":{
        "model":LinearRegression(),
        "params":{}
    },
    "DecisionTree":{
        "model":DecisionTreeRegressor(),
        "params":{"max_depth":[3,5,10],"min_samples_split":[2,5]}
    },
    "RandomForest":{
        "model":RandomForestRegressor(),
        "params":{"n_estimators":[50,100],"max_depth":[5,10]}
    }
}

# %%
best_models=[]

# %%
for name,config in models.items():
  print(f"Training{name}")

  grid=GridSearchCV(config["model"],config["params"],cv=5,scoring="neg_mean_squared_error")
  grid.fit(X_train,y_train)

  y_pred=grid.predict(X_test)
  rmse=np.sqrt(mean_squared_error(y_test,y_pred))
  r2=r2_score(y_test,y_pred)

  best_models.append({
      "model":name,
      "best_params":grid.best_params_,
      "rmse":rmse,
      "r2":r2
  })
# Out:
# TrainingLinearRegression
# TrainingDecisionTree
# TrainingRandomForest

# %%
best_models
# Out:
# [{'model': 'LinearRegression',
#   'best_params': {},
#   'rmse': np.float64(7.124029513677839),
#   'r2': 0.8349113861102166},
#  {'model': 'DecisionTree',
#   'best_params': {'max_depth': 5, 'min_samples_split': 2},
#   'rmse': np.float64(8.937012258512997),
#   'r2': 0.7401932630513586},
#  {'model': 'RandomForest',
#   'best_params': {'max_depth': 10, 'n_estimators': 100},
#   'rmse': np.float64(7.770540219889497),
#   'r2': 0.8035879509189212}]

# %%
results_df=pd.DataFrame(best_models)

# %%
results_df.sort_values(by="rmse")
# Out:
#               model                               best_params      rmse  \
# 0  LinearRegression                                        {}  7.124030
# 2      RandomForest    {'max_depth': 10, 'n_estimators': 100}  7.770540
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 2}  8.937012
#
#          r2
# 0  0.834911
# 2  0.803588
# 1  0.740193

# %%
import joblib

best_row=results_df.sort_values("rmse").iloc[0]

# %%
best_row
# Out:
# model          LinearRegression
# best_params                  {}
# rmse                    7.12403
# r2                     0.834911
# Name: 0, dtype: object

# %%
best_model_name=best_row["model"]

# %%
best_model_name
# Out:
# 'LinearRegression'

# %%
best_model_config=models[best_model_name]

# %%
best_model_config
# Out:
# {'model': LinearRegression(), 'params': {}}

# %%
final_model=best_model_config["model"]

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
joblib.dump(final_model,"best_model.pkl")
# Out:
# ['best_model.pkl']

# %%
joblib.load("best_model.pkl").predict(X_test)
# Out:
# array([ 80.46594508,  48.86907863,  89.92801771,  46.98667506,
#         43.50243593,  79.79071474,  87.05013225, 107.4516993 ,
#         62.67344973,  46.4743203 ,  83.76282292,  81.55564529,
#         63.09414629,  44.85583341,  91.99423492,  75.00352966,
#         82.47701204,  80.61992577,  61.2642645 ,  62.79878985,
#         57.380995  ,  92.71797491,  46.89711801,  80.04701348,
#         75.52807025,  66.09964476,  57.44126378,  34.72601698,
#         44.87432921,  58.56807717,  76.55263164, 102.67076152,
#         66.56581535,  89.1592608 ,  90.10938622,  52.00021266,
#         57.71722366,  74.8589124 ,  62.14063155,  91.69729711,
#         85.15391158,  61.47538447,  75.11171869,  69.53796476,
#         86.93258518,  85.86069868,  79.37860514,  66.85495635,
#         98.48292768,  95.80735843,  68.15955942,  78.89156923,
#         80.70978686,  49.74310692,  87.66820478,  72.41928765,
#         61.28183191,  86.41513985,  60.05075545,  74.5910171 ,
# ...
